# %% [markdown]
# __Inference__

# %%
#Import Library
import json
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# __loading Model__

# %%
#loading the model and necessary files
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# %% [markdown]
# __Data Dummy__

# %%
#data dummy

df = pd.read_csv('test.csv')


df
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe31003300390039003000      2008-12-10  Female      Service
# 1      fffe31003300310037003800      2008-08-14  Female      Product
# 2      fffe33003400380035003900      2008-11-13    Male      Product
# 3          fffe3100370039003200      2008-02-07  Female      Service
# 4      fffe32003600390036003700      2008-07-17  Female      Product
# ...                         ...             ...     ...          ...
# 12245      fffe3900310034003700      2008-10-02  Female      Service
# 12246  fffe32003600330034003000      2008-03-31  Female      Product
# 12247  fffe31003800340039003000      2008-02-12    Male      Service
# 12248  fffe32003600380031003800      2008-02-06    Male      Service
# 12249  fffe32003100390037003800      2008-08-05  Female      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  5.0
# ...

# %% [markdown]
# __Model Definition__

# %%
#display model
model
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   ['Designation',
#                                                    'Resource Allocation',
#                                                    'Mental Fatigue Score']),
#                                                  ('encoding', OneHotEncoder(),
#                                                   ['Gender',
#                                                    'WFH Setup Available'])])),
#                 ('classifier',
#                  LGBMRegressor(learning_rate=0.05, max_depth=15,
#                                num_leaves=50))])

# %%
#prediction results
y_pred_inf = model.predict(df)
y_pred_inf
# Out:
# array([0.60811065, 0.3599457 , 0.42087916, ..., 0.83161827, 0.57497887,
#        0.1257767 ])

# %%
#combine prediction results with dataset.
df['Burn Rate Prediction'] = y_pred_inf
df.head(50)
# Out:
#                  Employee ID Date of Joining  Gender Company Type  \
# 0   fffe31003300390039003000      2008-12-10  Female      Service
# 1   fffe31003300310037003800      2008-08-14  Female      Product
# 2   fffe33003400380035003900      2008-11-13    Male      Product
# 3       fffe3100370039003200      2008-02-07  Female      Service
# 4   fffe32003600390036003700      2008-07-17  Female      Product
# 5       fffe3600390032003200      2008-09-19    Male      Product
# 6       fffe3600370032003200      2008-01-16  Female      Service
# 7   fffe32003900390030003000      2008-02-10    Male      Service
# 8       fffe3100370031003000      2008-08-10    Male      Product
# 9   fffe31003500320037003600      2008-05-20    Male      Product
# 10      fffe3400370031003100      2008-12-17    Male      Service
# 11  fffe32003800300035003300      2008-03-26  Female      Service
# 12  fffe31003700380037003700      2008-02-27    Male      Service
# ...

# %% [markdown]
# The model can work to predict employee burn out scores. The prediction results have a root mean squared error value of 0.052 so that the results predicted by the model have original values in the range -0.052 to +0.052
